# %%
import requests
url = "https://course.ncku.edu.tw/index.php?c=qry11215&m=en_query&i=VjADNAg2AjFVe1UjVjhRYQ06DHcENAAuW2kAYgA3ATNTZwcrUGwAPwpiVTtdNgBvUTQDO1ZqBz8IIAdyVD4CPFlkAyxaIFQ2C3wAPlN0ADtcYAppUCEMMQohBT0FdQ5wBHlUOQdjVGtQI1dyViYBbgFkVGwHOlJqASkAewAjBTNWYAM0CCcCbFUiVWtWYFFqDTEMbgQq"
res = requests.get(url)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, "html.parser")

# %%
tr_tags = soup.select('tbody > tr')

# Initialize an empty list to store dictionaries for each row
data_list = []

# Loop through each tr tag
for tr_tag in tr_tags:
    # Extract the relevant data from each td tag within the tr tag
    tds = tr_tag.find_all('td')
    if len(tds) == 10:  # Ensure it's the correct row with 9 td elements
        department = tds[0].text.strip()
        dept_seq = tds[1].find('div', class_='dept_seq').text.strip()
        course_code = tds[1].text
        department_type = tds[3].text.strip()
        course_name = tds[4].find('a')#.text.strip()
        credit = tds[5].text#.strip()
        instructor = tds[6].text.strip()
        enrollment_status = tds[7].text.strip()
        location = tds[8].text.strip()

        tmp = location.split(' ')
        if len(tmp) == 3:
            location_obj = {'time': tmp[0], 'building': tmp[1], 'room': tmp[2]}
        else:
            location_obj = tmp
        
        # Create a dictionary for each row and append it to the data_list
        data_dict = {
            'Department': department,
            'Department Sequence': dept_seq,
            'Course Code': course_code,
            'Department Type': department_type,
            'Course Name': course_name,
            'Credit': credit,
            'Instructor': instructor,
            'Enrollment Status': enrollment_status,
            'Location': location_obj
        }
        data_list.append(data_dict)

# %%
import pandas as pd
df = pd.DataFrame(data_list)
df
# Out:
#        Department Department Sequence                   Course Code  \
# 0        外語中心 FLC              A1-101  A1-101 A110500-1  [FLC1016]
# 1        外語中心 FLC              A1-102  A1-102 A110600-2  [FLC1017]
# 2        外語中心 FLC              A1-103  A1-103 A110700-3  [FLC1018]
# 3        外語中心 FLC              A1-104  A1-104 A117600-4  [FLC1031]
# 4        外語中心 FLC              A1-105  A1-105 A110900-5  [FLC1020]
# ..            ...                 ...                           ...
# 994  跨域國際碩士學程 MSS              W1-011       W1-011 W160100  [6001]
# 995  跨域國際碩士學程 MSS              W1-021       W1-021 W160200  [6003]
# 996       熱植所 TPS              Z3-005    Z3-005 Z352800  [TPS6894]
# 997       熱植所 TPS              Z3-007    Z3-007 Z352600  [TPS6819]
# 998    譯農博士學程 TAS              Z5-005    Z5-005 Z352800  [TPS6894]
#
#     Department Type      Course Name Credit                  Instructor  \
# 0              外國語言         [基礎學術英文]  2  必修                         鍾淑玫
# 1              外國語言         [基礎學術溝通]  2  必修                         賴諭萱
# 2              外國語言          [跨文化溝通]  2  必修                         陳安純
# 3              外國語言           [職場英文]  2  必修                         辛佳玲
# 4              外國語言         [人文醫學英文]  2  必修                         許富貴
# ..              ...              ...    ...                         ...
# 994              講義  [複雜環境議題系統思考與建模]  3  選修                          未定
# 995              實習         [永續發展實習]  1  選修                       哈里森約翰
# 996              講義     [植物生理與微生物體學]  3  必修  李瑞花*方素瓊邱啟洲黃兆立山田昌史林哲揚林耀正劉明容
# 997              講義      [實驗設計與方法專論]  2  選修                  邱啟洲*李瑞花高木優
# 998              講義     [植物生理與微生物體學]  3  必修  李瑞花*方素瓊邱啟洲黃兆立山田昌史林哲揚林耀正劉明容
#
#     Enrollment Status                                           Location
# 0                0/37  {'time': '[1]2~3', 'building': '修齊大樓', 'room':...
# 1                0/37  {'time': '[1]2~3', 'building': '修齊大樓', 'room':...
# 2                0/37  {'time': '[1]2~3', 'building': '修齊大樓', 'room':...
# 3                0/37  {'time': '[1]2~3', 'building': '修齊大樓', 'room':...
# 4                0/37  {'time': '[1]2~3', 'building': '修齊大樓', 'room':...
# ..                ...                                                ...
# 994              2/43                                           [[1]6~8]
# 995              0/30  {'time': '[1]5~6', 'building': '唯農大樓', 'room':...
# 996              8/22  {'time': '[1]6~8', 'building': '生科院大樓', 'room'...
# 997              8/22  {'time': '[1]9~A', 'building': '生科院大樓', 'room'...
# 998              8/22  {'time': '[1]6~8', 'building': '生科院大樓', 'room'...
#
# [999 rows x 9 columns]

# %%
df['Department'].unique()
# Out:
# array(['外語中心 FLC', '體育室 OPE', '軍訓室 MT', '師培中心 CTE', '大學國文 CL', '通識中心 GE',
#        '共同英授 GCTE', '華語中心 CLC', '不分系學程 CCEP', '文學院學士班 CLA', '中文系 CL',
#        '外文系 FLL', '歷史系 HIS', '台文系 TWL', '數學系 MATH', '', '物理系 PHYS',
#        '化學系 CHEM', '地科系 EARS', '生科系 LS', '生技系 BBS', '法律系 LAW', '政治系 PS',
#        '經濟系 ECON', '心理系 PSY', '工學院 COE', '機械系 ME', '電機系 EE', '化工系 CHE',
#        '資源系 RE', '材料系 MSE', '土木系 CE', '建築系 ARCH', '水利系 HOE', '工科系 ES',
#        '能源學程 IBPE', '系統系 SNME', '都計系 UP', '工設系 ID', '航太系 AA', '環工系 EV',
#        '測量系 GM', '資訊系 CSIE', '光電系 DPS', '醫工系 BME', '會計系 ACC', '統計系 STAT',
#        '工資系 IIM', '企管系 BA', '交管系 TCM', '護理系 NURS', '醫技系 MLSB', '醫學系 MED',
#        '物治系 PT', '職治系 OT', '藥學系 DOPA', '牙醫系 DEN', '中文所 CL', '外文所 FLL',
#        '歷史所 HIS', '藝術所 AS', '台文所 TWL', '考古所 Arxe', '戲劇碩士學程 AD',
#        '應數所 MATH', '物理所 PHYS', '化學所 CHEM', '地科所 EARS', '生科所 LS',
#        '生技所 BBS', '光電所 DPS', '電漿所 SAPS', '敏求學院課程 SOC', '晶片學程 PICD',
#        '製程學程 PSMT', '封測學程 PSPT', '關鍵材料學程 KMAT', '永續學程 PSSM', '工程管理碩專 EM',
#        '機械所 ME', '電機所 EE', '化工所 CHE', '資源所 RE', '材料所 MSE', '土木所 CE',
#        '建築所 ARCH', '水利所 HOE', '工科所 ES', '海事所 OTMA', '尖端碩士學程 icam',
#        '自災碩士學程 iNHM', '人工智慧碩士學程', '智慧製造碩士學程 iCIM', '機器人碩士學程 AIRO',
#        '運算碩士學程 ICM', '運算工程博士學程 ICID', '能源碩博學程 IBPE', '系統所 SYS', '都計所 UP',
#        '航太所 AA', '環工所 EV', '測量所 GM', '資訊所 CSIE', '醫工所 BME', '製造所 IMIS',
#        '創意所 ICID', '科藝碩士學程 TART', '微電所 IME', '電通所 CCE', '民航所 CA',
#        '醫資所 IMI', '奈積碩博學程 NICE', '太空所 ISSE', 'ＥＭＢＡ碩專 EMBA', '會計所 ACC',
#        '統計所 STAT', '工資所 IIM', '企管所 BA', '國企所 IB', '資管所 IM', '財金所 FIN',
#        '電管所 TM', '國經所 IMBA', '體健所 PEHL', 'AMBA碩士學程 AMBA', '數據所 DS',
#        '生化所 BIMB', '藥理所 PHAR', '生理所 PHSL', '微免所 MI', '基醫所 BMS',
#        '臨藥科技所 CPPS', '環醫所 EOH', '行醫所 BM', '臨醫所 CM', '食安所 FSRM', '分醫所 IMM',
#        '護理所 NURS', '醫技所 MLSB', '口醫所 IOM', '物治所 PT', '職治所 OT', '公衛所 PH',
#        '細胞所 CBA', '老年所 GERO', '政經所 PE', '法律所 LAW', '教育所 EDU', '經濟所 ECON',
#        '心理所 CS', '電力產碩 MPPE', '電子產碩 MPPE', '電機驅動產碩', '微波元件產碩', '機械產碩 ME',
#        '財金產碩 FIIM', '金融資訊產碩', '光電半導體產碩', '光電材料產碩', '資訊產碩', '會計商業產碩 ACIM',
#        '跨域國際碩士學程 MSS', '熱植所 TPS', '譯農博士學程 TAS'], dtype=object)

# %%
df[df['Department'] == '通識中心 GE']
# Out:
#    Department Department Sequence                  Course Code  \
# 72    通識中心 GE              A9-105  A9-105 A974500-1  [GE2214]
# 73    通識中心 GE              A9-107    A9-107 A959800  [GE2205]
# 74    通識中心 GE              A9-120    A9-120 A92S900  [GE2066]
# 75    通識中心 GE              A9-121  A9-121 A93E700-1  [GE2089]
# 76    通識中心 GE              A9-205    A9-205 A962902  [GE2406]
# 77    通識中心 GE              A9-206    A9-206 A965001  [GE2409]
# 78    通識中心 GE              A9-207    A9-207 A962201  [GE2404]
# 79    通識中心 GE              A9-209    A9-209 A952502  [GE2403]
# 80    通識中心 GE              A9-214    A9-214 A966001  [GE2407]
# 81    通識中心 GE              A9-219    A9-219 A965201  [GE2425]
# 82    通識中心 GE              A9-223    A9-223 A960502  [GE2405]
# 83    通識中心 GE              A9-229    A9-229 A961401  [GE2408]
# 84    通識中心 GE              A9-304  A9-304 A932002-1  [GE2302]
# 85    通識中心 GE              A9-308    A9-308 A930903  [GE2305]
# 86    通識中心 GE              A9-401    A9-401 A92N700  [GE2439]
# 87    通識中心 GE              A9-413    A9-413 A942300  [GE2521]
# 88    通識中心 GE              A9-417    A9-417 A92H800  [GE2583]
# 89    通識中心 GE              A9-701    A9-701 A92Q600  [GE2033]
#
#    Department Type    Course Name Credit  \
# 72            社會科學          [心理學]  2  必修
# 73            社會科學         [創意思考]  2  必修
# 74            社會科學      [老化與生活綜論]  3  必修
# 75            社會科學        [生活經濟學]  2  必修
# 76         生命科學與健康         [疾病媒介]  2  必修
# 77         生命科學與健康    [與婦產科醫師的對話]  2  必修
# 78         生命科學與健康        [生物多樣性]  2  必修
# 79         生命科學與健康      [情緒與壓力管理]  2  必修
# 80         生命科學與健康     [兒童青少年的健康]  2  必修
# 81         生命科學與健康        [醫學與健康]  2  必修
# 82         生命科學與健康      [身體結構與功能]  2  必修
# 83         生命科學與健康       [生物技術概論]  2  必修
# 84         自然與工程科學      [應用化學與實驗]  2  必修
# 85         自然與工程科學       [材料科技概論]  2  必修
# 86            科際整合        [醫療與文化]  2  必修
# 87            科際整合  [全球暖化與極端氣候事件]  2  必修
# 88            科際整合   [從創意發明到專利保護]  2  必修
# 89            融合通識      [使用者經驗設計]  3  必修
#
#                                Instructor Enrollment Status  \
# 72                                    林君昱            219/額滿
# 73                                    梁文韜            55/105
# 74                             陳麗光*楊登棋翁慧卿              9/27
# 75                                    宋皇叡             73/額滿
# 76                                林威辰*鄭尉弘             59/22
# 77                                    劉明道              49/2
# 78          麥愛堂*蔣鎮宇李亞夫邱慈暉陳一菁仲澤剛史許祐薰吳文鑾楊永年            109/額滿
# 79                                    鄭淑惠             73/額滿
# 80                                    邱元佑              38/5
# 81                             張金石*陳育堂楊宜杰             73/額滿
# 82                                    吳晉祥            33/113
# 83  林士鳴*陳宗嶽張清俊洪健睿陳逸民王涵青張純純盧福翊呂曉沛陳盈嵐陳俊榮張文綺            109/額滿
# 84                                    謝慕道              5/21
# 85                                    林光隆             51/額滿
# 86                                    石明人             15/21
# 87                                    劉正千             24/41
# 88                                    張桂豪             45/20
# 89                                    黃仲菁             18/額滿
#
#                   Location
# 72                  [1]7~8
# 73       [1]7~8 共同教室 A1302
# 74       [1]6~8 共同教室 A1301
# 75      [1]5~6 社科院大樓 80103
# 76      [1]7~8 系統系館 視廳教室1F
# 77  [1]7~8 雲平大樓 27103(通識中心
# 78    [1]7~8 生科院大樓南側 893S1
# 79      [1]7~8 資訊大樓 格致廳小講堂
# 80          [1]7~8 醫學院 501
# 81  [1]5~6 雲平大樓 27103(通識中心
# 82         [1]7~8 醫學院 第四講堂
# 83         [1]7~8 化工系館 華立廳
# 84       [1]7~8 理化大樓 35102
# 85   [1]7~8 照坤精密儀器大樓 95403
# 86       [1]5~6 工科系館 41103
# 87       [1]7~8 唯農大樓 許文龍講堂
# 88  [1]7~8 共同教室 A1307(資源後)
# 89      [1]6~8 規劃設計大樓 5107
